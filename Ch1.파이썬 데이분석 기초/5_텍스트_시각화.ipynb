# %% [markdown]
# <a href="https://colab.research.google.com/github/bakeunbi99/Colab/blob/main/Ch1.%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%8D%B0%EC%9D%B4%EB%B6%84%EC%84%9D%20%EA%B8%B0%EC%B4%88/5_%ED%85%8D%EC%8A%A4%ED%8A%B8_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/10/18 16:58
내용 : 파이썬 텍스트 시각화 실습
"""

import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image

# %%
# 텍스트 파일 불러오기
txt = open('/content/drive/MyDrive/Colab Notebooks/file/wordcloud_data.txt').read()
txt

# %%
# 워드클라우드 출력
wc = WordCloud(width=1200, 
               height=1200,
               font_path='/content/drive/MyDrive/Colab Notebooks/file/malgun.ttf',
               background_color='white').generate(txt)
plt.imshow(wc, interpolation='bilinear')
plt.show()
